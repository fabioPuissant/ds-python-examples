# %%
import pandas
import os

# %%
df1 = pandas.DataFrame([[1,2,3],[10,20,30]], columns=["Name", "Price", "Stock"])

# %%
df1
# Out:
#    Name  Price  Stock
# 0     1      2      3
# 1    10     20     30

# %% [markdown]
# **Clip 110: Reading cvs Files**

# %%
supermarkets_csv_df = pandas.read_csv("C:\\Users\\fabio\\Jupyter-notebooks\\data\\supermarkets\\supermarkets.csv")
supermarkets_csv_df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# **Clip 111: Reading json Files**

# %%
supermarkets_json_df = pandas.read_json("C:\\Users\\fabio\\Jupyter-notebooks\\data\\supermarkets\\supermarkets.json")
supermarkets_json_df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# **Clip 114 Reading Excel files**

# %%
supermarkets_xlsx_df = pandas.read_excel("C:\\Users\\fabio\\Jupyter-notebooks\\data\\supermarkets\\supermarkets.xlsx", 
                                         sheet_name=0)
supermarkets_xlsx_df
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %% [markdown]
# **Clip 115 Reading txt files that are character separated**

# %%
#if txt file is comma separated => use the read_csv() method without specifying the separtation character => default is ','
supermarkets_txt_comma_df = pandas.read_csv("C:\\Users\\fabio\\Jupyter-notebooks\\data\\supermarkets\\supermarkets-commas.txt")
supermarkets_txt_comma_df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
#Else use the  read_csv() method with specifying a separtation character => in this case';'
supermarkets_txt_semi_colons_df =pandas.read_csv(
    "C:\\Users\\fabio\\Jupyter-notebooks\\data\\supermarkets\\supermarkets-semi-colons.txt",
    sep=";"
)
supermarkets_txt_semi_colons_df
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# **Remove the Header Row of a data-frame**

# %%
df_no_header_row = pandas.read_csv("C:\\Users\\fabio\\Jupyter-notebooks\\data\\supermarkets\\supermarkets-commas.txt", 
                                   header = None)
df_no_header_row          
#Notice that the column names are indexes and the column names that were provided in the file are used as data in a row!!
# Out:
#     0                1              2                 3        4            5  \
# 0  ID          Address           City             State  Country         Name
# 1   1     3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2   2   735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3   3      332 Hill St  San Francisco  California 94114      USA  Super River
# 4   4     3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   5  1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#            6
# 0  Employees
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %% [markdown]
# **Set the colom-names of an existing data-frame**

# %%
df_no_header_row.columns = ["ID","Address","City","State", "Country", "Name", "Employees"]
df_no_header_row
# Out:
#    ID          Address           City             State  Country         Name  \
# 0  ID          Address           City             State  Country         Name
# 1   1     3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2   2   735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3   3      332 Hill St  San Francisco  California 94114      USA  Super River
# 4   4     3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   5  1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#    Employees
# 0  Employees
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %% [markdown]
# **Set index column**

# %%
df_no_header_row.set_index("ID") #This is NOT permanent!!
# Out:
#             Address           City             State  Country         Name  \
# ID
# ID          Address           City             State  Country         Name
# 1      3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114      USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#     Employees
# ID
# ID  Employees
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
#To have it permanent you must copy the data-frame into a variable!
df9=df_no_header_row.set_index("ID")
df9
# Out:
#             Address           City             State  Country         Name  \
# ID
# ID          Address           City             State  Country         Name
# 1      3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114      USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#     Employees
# ID
# ID  Employees
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
# OR use 
#To have it permanent you must copy the data-frame into a variable!
df_no_header_row.set_index("Name", inplace = True, drop = False)
df_no_header_row
# Out:
#              ID          Address           City             State  Country  \
# Name
# Name         ID          Address           City             State  Country
#  Madeira      1     3666 21st St  San Francisco          CA 94114      USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119      USA
# Super River   3      332 Hill St  San Francisco  California 94114      USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114      USA
# Sanchez       5  1056 Sanchez St  San Francisco        California      USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114      USA
#
#                     Name  Employees
# Name
# Name                Name  Employees
#  Madeira         Madeira          8
# Bready Shop  Bready Shop         15
# Super River  Super River         25
# Ben's Shop    Ben's Shop         10
# Sanchez          Sanchez         12
# Richvalley    Richvalley         20

# %% [markdown]
# **Indexing and Slicing** <Label Based indexing (colum and index names)>

# %%
#Label BAsed indexing (colum and index names)
df7= df9.set_index("Address", drop=False) #Just set-up

# Getting some celss
df7.loc["735 Dolores St":"332 Hill St","Country":"Name"] #[<Indexes>, <Columns>]
# Out:
#                Country         Name
# Address
# 735 Dolores St     USA  Bready Shop
# 332 Hill St        USA  Super River

# %%
# You can also get single cells
df7.loc["332 Hill St", "Country"]
# Out:
# 'USA'

# %%
df7.loc[:, "Country"]
# Out:
# Address
# Address            Country
# 3666 21st St           USA
# 735 Dolores St         USA
# 332 Hill St            USA
# 3995 23rd St           USA
# 1056 Sanchez St        USA
# 551 Alvarado St        USA
# Name: Country, dtype: object

# %%
#Better to have a list
list(df7.loc[:, "Country"])
# Out:
# ['Country', 'USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %% [markdown]
# **Indexing and Slicing** (Index Based indexing)

# %%
df7
# Out:
#                          Address           City             State  Country  \
# Address
# Address                  Address           City             State  Country
# 3666 21st St        3666 21st St  San Francisco          CA 94114      USA
# 735 Dolores St    735 Dolores St  San Francisco          CA 94119      USA
# 332 Hill St          332 Hill St  San Francisco  California 94114      USA
# 3995 23rd St        3995 23rd St  San Francisco          CA 94114      USA
# 1056 Sanchez St  1056 Sanchez St  San Francisco        California      USA
# 551 Alvarado St  551 Alvarado St  San Francisco          CA 94114      USA
#
#                         Name  Employees
# Address
# Address                 Name  Employees
# 3666 21st St         Madeira          8
# 735 Dolores St   Bready Shop         15
# 332 Hill St      Super River         25
# 3995 23rd St      Ben's Shop         10
# 1056 Sanchez St      Sanchez         12
# 551 Alvarado St   Richvalley         20

# %%
#Use the iloc() method
df7.iloc[2:4,1:3] #Upperbound exclusice!
# Out:
#                          City             State
# Address
# 735 Dolores St  San Francisco          CA 94119
# 332 Hill St     San Francisco  California 94114

# %%
df7.iloc[1:4,1:4]
# Out:
#                          City             State Country
# Address
# 3666 21st St    San Francisco          CA 94114     USA
# 735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St     San Francisco  California 94114     USA

# %%
df7.iloc[:,1:3]
# Out:
#                           City             State
# Address
# Address                   City             State
# 3666 21st St     San Francisco          CA 94114
# 735 Dolores St   San Francisco          CA 94119
# 332 Hill St      San Francisco  California 94114
# 3995 23rd St     San Francisco          CA 94114
# 1056 Sanchez St  San Francisco        California
# 551 Alvarado St  San Francisco          CA 94114

# %%
df7.iloc[2,1:3]
# Out:
# City     San Francisco
# State         CA 94119
# Name: 735 Dolores St, dtype: object

# %% [markdown]
# **Deleting Column and Rows**

# %%
df7.drop("City",1) #Not permanent! Second param 0=Rows, 1=Columns
# Out:
#                          Address             State  Country         Name  \
# Address
# Address                  Address             State  Country         Name
# 3666 21st St        3666 21st St          CA 94114      USA      Madeira
# 735 Dolores St    735 Dolores St          CA 94119      USA  Bready Shop
# 332 Hill St          332 Hill St  California 94114      USA  Super River
# 3995 23rd St        3995 23rd St          CA 94114      USA   Ben's Shop
# 1056 Sanchez St  1056 Sanchez St        California      USA      Sanchez
# 551 Alvarado St  551 Alvarado St          CA 94114      USA   Richvalley
#
#                  Employees
# Address
# Address          Employees
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df7
# Out:
#                          Address           City             State  Country  \
# Address
# Address                  Address           City             State  Country
# 3666 21st St        3666 21st St  San Francisco          CA 94114      USA
# 735 Dolores St    735 Dolores St  San Francisco          CA 94119      USA
# 332 Hill St          332 Hill St  San Francisco  California 94114      USA
# 3995 23rd St        3995 23rd St  San Francisco          CA 94114      USA
# 1056 Sanchez St  1056 Sanchez St  San Francisco        California      USA
# 551 Alvarado St  551 Alvarado St  San Francisco          CA 94114      USA
#
#                         Name  Employees
# Address
# Address                 Name  Employees
# 3666 21st St         Madeira          8
# 735 Dolores St   Bready Shop         15
# 332 Hill St      Super River         25
# 3995 23rd St      Ben's Shop         10
# 1056 Sanchez St      Sanchez         12
# 551 Alvarado St   Richvalley         20

# %%
df7.drop("332 Hill St",0)  #Not permanent! Second param 0=Rows, 1=Columns
# Out:
#                          Address           City       State  Country  \
# Address
# Address                  Address           City       State  Country
# 3666 21st St        3666 21st St  San Francisco    CA 94114      USA
# 735 Dolores St    735 Dolores St  San Francisco    CA 94119      USA
# 3995 23rd St        3995 23rd St  San Francisco    CA 94114      USA
# 1056 Sanchez St  1056 Sanchez St  San Francisco  California      USA
# 551 Alvarado St  551 Alvarado St  San Francisco    CA 94114      USA
#
#                         Name  Employees
# Address
# Address                 Name  Employees
# 3666 21st St         Madeira          8
# 735 Dolores St   Bready Shop         15
# 3995 23rd St      Ben's Shop         10
# 1056 Sanchez St      Sanchez         12
# 551 Alvarado St   Richvalley         20

# %%
df7.drop(df7.index[0:3],0)
# Out:
#                          Address           City             State Country  \
# Address
# 332 Hill St          332 Hill St  San Francisco  California 94114     USA
# 3995 23rd St        3995 23rd St  San Francisco          CA 94114     USA
# 1056 Sanchez St  1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St  551 Alvarado St  San Francisco          CA 94114     USA
#
#                         Name Employees
# Address
# 332 Hill St      Super River        25
# 3995 23rd St      Ben's Shop        10
# 1056 Sanchez St      Sanchez        12
# 551 Alvarado St   Richvalley        20

# %%
df7.drop(df7.columns[0:3],1)

# %%
df7=df7.drop("Address", 0) #Dropped the unnessary row headers that were in the initial file

# %% [markdown]
# **Getting the index names and column names**

# %%
df7.index
# Out:
# Index(['3666 21st St', '735 Dolores St', '332 Hill St', '3995 23rd St',
#        '1056 Sanchez St', '551 Alvarado St'],
#       dtype='object', name='Address')

# %%
df7.columns
# Out:
# Index(['Address', 'City', 'State', 'Country', 'Name', 'Employees',
#        'Continent'],
#       dtype='object')

# %% [markdown]
# **(Manipulating rows and columns) Updating and Adding new Columns and Rows**

# %%
df7
# Out:
#                          Address           City             State Country  \
# Address
# 3666 21st St        3666 21st St  San Francisco          CA 94114     USA
# 735 Dolores St    735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St          332 Hill St  San Francisco  California 94114     USA
# 3995 23rd St        3995 23rd St  San Francisco          CA 94114     USA
# 1056 Sanchez St  1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St  551 Alvarado St  San Francisco          CA 94114     USA
#
#                         Name Employees           Continent
# Address
# 3666 21st St         Madeira         8  USA, North America
# 735 Dolores St   Bready Shop        15  USA, North America
# 332 Hill St      Super River        25  USA, North America
# 3995 23rd St      Ben's Shop        10  USA, North America
# 1056 Sanchez St      Sanchez        12  USA, North America
# 551 Alvarado St   Richvalley        20  USA, North America

# %%
#First get the length of your indexes (rows)
len(df7.index)
# Out:
# 6

# %%
df7["Continent"] = df7.shape[0] * ["North America"] 
#shape[0] is the number of rows in that data-frame, shape[1] is the number of columns
#So you just multiply it with the data-value that needs to be inserted in the data-cells of the new column
df7
# Out:
#                          Address           City             State Country  \
# Address
# 3666 21st St        3666 21st St  San Francisco          CA 94114     USA
# 735 Dolores St    735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St          332 Hill St  San Francisco  California 94114     USA
# 3995 23rd St        3995 23rd St  San Francisco          CA 94114     USA
# 1056 Sanchez St  1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St  551 Alvarado St  San Francisco          CA 94114     USA
#
#                         Name Employees      Continent
# Address
# 3666 21st St         Madeira         8  North America
# 735 Dolores St   Bready Shop        15  North America
# 332 Hill St      Super River        25  North America
# 3995 23rd St      Ben's Shop        10  North America
# 1056 Sanchez St      Sanchez        12  North America
# 551 Alvarado St   Richvalley        20  North America

# %%
#An example of the possibilities on updating a column
df7["Continent"] = df7["Country"] + ", " + "North America"
df7
# Out:
#                          Address           City             State Country  \
# Address
# 3666 21st St        3666 21st St  San Francisco          CA 94114     USA
# 735 Dolores St    735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St          332 Hill St  San Francisco  California 94114     USA
# 3995 23rd St        3995 23rd St  San Francisco          CA 94114     USA
# 1056 Sanchez St  1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St  551 Alvarado St  San Francisco          CA 94114     USA
#
#                         Name Employees           Continent
# Address
# 3666 21st St         Madeira         8  USA, North America
# 735 Dolores St   Bready Shop        15  USA, North America
# 332 Hill St      Super River        25  USA, North America
# 3995 23rd St      Ben's Shop        10  USA, North America
# 1056 Sanchez St      Sanchez        12  USA, North America
# 551 Alvarado St   Richvalley        20  USA, North America

# %% [markdown]
# **Reversing the Columns with the Rows**

# %%
df7_t = df7.T
df7_t
# Out:
# Address          3666 21st St      735 Dolores St         332 Hill St  \
# Address          3666 21st St      735 Dolores St         332 Hill St
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114          California            CA 94114
# Country                   USA                 USA                 USA
# ...
